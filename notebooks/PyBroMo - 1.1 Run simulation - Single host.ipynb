# %% [markdown]
# # Brownian Motion simulation on a single host

# %% [markdown]
# The following initialization script will enter the `brownian` dir,
# load the `brownian` functions and some other useful IPython functions:

# %%
# %run -i load_bromo.py
# Out:
# /home/anto/Documents/ucla/src/brownian

# %% [markdown]
# Let load the simulation functions and define the simulation parameters by running `brownian.py`. Default simulation paramenters are:
#
#     # Simulation time step
#     t_step = 0.5e-6   # seconds
#
#     # Diffusion coefficient
#     Du = 12.0        # um^2 / s
#     D = Du*(1e-6)**2
#
#     # Number of samples to simulate
#     t_max = 0.1 # seconds
#     N_samples = int(t_max/t_step)
#
#     # PSF definition
#     psf = NumericPSF()
#
#     # Box definition
#     box = Box(x1=-4.e-6,x2=4.e-6,y1=-4.e-6,y2=4.e-6,z1=-6e-6,z2=6e-6)
#
#     # Particles definition
#     P = gen_particles(1, box)
#
#     # Particle simulation
#     S = Particles_in_a_box(D=D, t_step=t_step, particles=P, box=box, psf=psf)

# %%
# %matplotlib inline

# %%
# %run -i brownian.py

# %%
# Initialize the random seed to a fixed value (for reproducibility)
np.random.seed(6)

# Simulation time step
t_step = 0.5e-6   # seconds

# Number of samples to simulate
t_max = .2 # seconds

# Particles definition
P = gen_particles(2, box)

# Particle simulation
S = Particles_in_a_box(D=D, t_step=t_step, t_max=t_max, particles=P, box=box, psf=psf)

# %% [markdown]
# Before running the simulation be sure you have enogh RAM for the current parameters.
# For example only to store the emission array you will need:

# %%
S.print_RAM()
# Out:
#   Number of particles: 2
#   Number of time steps: 400000
#   Emission array size: 3.0 MB (total_emission=True)
#   Emission array size: 6.0 MB (total_emission=False)
#   Position array size: 18.0 MB

# %%
S.sim_motion_em(total_emission=True, delete_pos=False)
# Out:
# [11150] Simulating particle 0
# [11150] Simulating particle 1

# %%
# This requires delete_pos=False in .sim_motion_em()
plot_tracks(S)

# %%
plot_emission(S, multi=True)

# %%
S.sim_timetrace(max_em_rate=3e5, bg_rate=2e3)

# %%
plot_timetrace(S, scroll_gui=False)

# %%
S.name
# Out:
# 'D1.2e-11_2P_4pM_step0.5us_t_max0.2s_ID0-0'

# %%
S._compact_repr_core()
# Out:
# 'D1.2e-11_2P_4pM_step0.5us_ID0'

# %%
S._compact_repr()
# Out:
# 'D1.2e-11_2P_4pM_step0.5us_t_max0.2s_ID0-0'

# %% [markdown]
# # Save and load simulations

# %%
cd $BROWN_DIR
# Out:
# /home/anto/Documents/ucla/src/brownian

# %%
SIM_DIR = "../data/sim/brownian/objects/"
S.dump(dir_=SIM_DIR)
# Out:
# Saved to ../data/sim/brownian/objects//bromo_sim_id0-0_D1.2e-11_P2_step0.5us_t_max0.2s.pickle

# %%
SIM_DIR = "../data/sim/brownian/objects/"
S2 = S.load(dir_=SIM_DIR)
# Out:
# Loaded: ../data/sim/brownian/objects//bromo_sim_id0-0_D1.2e-11_P2_step0.5us_t_max0.2s.pickle

# %%
S2
# Out:
# Box: X 8.0um, Y 8.0um, Z 12.0um
# D 1.2e-11, #Particles 2, t_step 0.5us, t_max 0.2s EID_ID 0 0

# %%
S
# Out:
# Box: X 8.0um, Y 8.0um, Z 12.0um
# D 1.2e-11, #Particles 2, t_step 0.5us, t_max 0.2s EID_ID 0 0

# %%
S2.em
# Out:
# array([[  7.84983849e-07,   7.84919671e-07,   7.92120295e-07, ...,
#           1.76593796e-05,   1.76628897e-05,   1.76252189e-05]])

# %%
print id(S2.em), id(S.em)
# Out:
# 117183952 61945120

# %%
(S.em == S2.em).all()
# Out:
# True

# %%
# %qtconsole

# %%
cd $NOTEBOOK_DIR
# Out:
# /home/anto/Documents/ucla/src/notebooks/private

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom2.css", "r").read()
    return HTML(styles)
css_styling().
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:820px;
#         margin-left:8% !important;
#         margin-right:auto;
#     }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 120%;
#         font-size: 110%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     blockquote  p {
# 	/*margin: 1em 2em;*/
# 	line-height: 140%;
#     }
#
#     .rendered_html code {
# 	background-color: #f7f7f7;
# 	border: 1px solid #dddddd;
# 	color: black;
# 	line-height: 1.1em;
#     	padding: 0.15em;
# 	font-size: 85%;
#     }
#
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     /*.prompt{
#         display: None;
#     }*/
#
# </style>
